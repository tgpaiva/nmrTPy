# %%
from  bruker.api.topspin import Topspin
from nmrTPy.process import Fit

top = Topspin()
dp = top.getDataProvider()

# %% [markdown]
# Simple fit example

# %%
path = '/opt/topspin4.3.0/data/2022_02917_PTDC/CHI_AERO_RB3_9_8_4_22/12/'

Fit.main(path, firstexpno = None, lastexpno = None,  fitmodel_ = 'Exp' , Nexp_ = 1, norm_ = 'y', fiterror_ = 'n', sterror_ = 'n', DOSY_ = False, save_ = 'y', prettyexcel_ = 'n')
# Out:
#           P            D1
# 0  0.995723  8.030658e-10
# /Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/nmrTPy/nmrTPy/process/Bruker_Pseudo2D.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   intfile = pd.read_csv(file_, names=[0,1], delim_whitespace=True , header  = 1, usecols = [0,1])
# array([9.95722928e-01, 8.03065847e-10])

# %%
path = '/opt/topspin4.4.0/data/PhD/CellPyrCl_23_03_2022/'

results = Fit.main(path, eps = [12, 10], firstexpno = 100, lastexpno = 103,  fitmodel_ = 'Exp' , Nexp_ = 1, norm_ = 'y', fiterror_ = 'n', sterror_ = 'n', DOSY_ = False, save_ = 'n', prettyexcel_ = 'n')
# Out:
# /Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/nmrTPy/nmrTPy/process/Bruker_Pseudo2D.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   intfile = pd.read_csv(file_, names=[0,1], delim_whitespace=True , header  = 1, usecols = [0,1])
